# %% [markdown]
# # Prediction of Diabetes using Artificial Neural Network

# %%
#Importing required Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Part 1: Data Gathering

# %%
#Importing dataset
diabetes_data = pd.read_csv('diabetes.csv')
print(diabetes_data)
# Out:
#        PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0        1354778            0            171                      80
# 1        1147438            8             92                      93
# 2        1640031            7            115                      47
# 3        1883350            9            103                      78
# 4        1424119            1             85                      59
# ...          ...          ...            ...                     ...
# 14995    1490300           10             65                      60
# 14996    1744410            2             73                      66
# 14997    1742742            0             93                      89
# 14998    1099353            0            132                      98
# 14999    1386396            3            114                      65
#
#        TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  \
# 0                    34            23  43.509726          1.213191   21
# 1                    47            36  21.240576          0.158365   23
# 2                    52            35  41.511523          0.079019   23
# 3                    25           304  29.582192          1.282870   43
# 4                    27            35  42.604536          0.549542   22
# ...                 ...           ...        ...               ...  ...
# 14995                46           177  33.512468          0.148327   41
# 14996                27           168  30.132636          0.862252   38
# 14997                43            57  18.690683          0.427049   24
# 14998                18           161  19.791645          0.302257   23
# 14999                47           512  36.215437          0.147363   34
#
#        Diabetic
# 0             0
# 1             0
# 2             0
# 3             1
# 4             0
# ...         ...
# 14995         1
# 14996         1
# 14997         0
# 14998         0
# 14999         1
#
# [15000 rows x 10 columns]

# %% [markdown]
# ## Part 2: Data Analysis

# %%
#Preview the data
diabetes_data.head()
# Out:
#    PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0    1354778            0            171                      80
# 1    1147438            8             92                      93
# 2    1640031            7            115                      47
# 3    1883350            9            103                      78
# 4    1424119            1             85                      59
#
#    TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  Diabetic
# 0                34            23  43.509726          1.213191   21         0
# 1                47            36  21.240576          0.158365   23         0
# 2                52            35  41.511523          0.079019   23         0
# 3                25           304  29.582192          1.282870   43         1
# 4                27            35  42.604536          0.549542   22         0

# %%
#Checking the shape of data that is number of rows and columns
diabetes_data.shape
# Out:
# (15000, 10)

# %%
#Checking the attributes of the dataset
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PatientID               15000 non-null  int64
#  1   Pregnancies             15000 non-null  int64
#  2   PlasmaGlucose           15000 non-null  int64
#  3   DiastolicBloodPressure  15000 non-null  int64
#  4   TricepsThickness        15000 non-null  int64
#  5   SerumInsulin            15000 non-null  int64
#  6   BMI                     15000 non-null  float64
#  7   DiabetesPedigree        15000 non-null  float64
#  8   Age                     15000 non-null  int64
#  9   Diabetic                15000 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 1.1 MB

# %%
#Deleting the patient ID column 
del diabetes_data['PatientID']

# %%
#Checking for null values
print (diabetes_data.isnull().values.any())
diabetes_data.isnull().sum()
# Out:
# False
# Pregnancies               0
# PlasmaGlucose             0
# DiastolicBloodPressure    0
# TricepsThickness          0
# SerumInsulin              0
# BMI                       0
# DiabetesPedigree          0
# Age                       0
# Diabetic                  0
# dtype: int64

# %%
#Statistical summary of data
diabetes_data.describe().T
# Out:
#                           count        mean         std        min        25%  \
# Pregnancies             15000.0    3.224533    3.391020   0.000000   0.000000
# PlasmaGlucose           15000.0  107.856867   31.981975  44.000000  84.000000
# DiastolicBloodPressure  15000.0   71.220667   16.758716  24.000000  58.000000
# TricepsThickness        15000.0   28.814000   14.555716   7.000000  15.000000
# SerumInsulin            15000.0  137.852133  133.068252  14.000000  39.000000
# BMI                     15000.0   31.509646    9.759000  18.200512  21.259887
# DiabetesPedigree        15000.0    0.398968    0.377944   0.078044   0.137743
# Age                     15000.0   30.137733   12.089703  21.000000  22.000000
# Diabetic                15000.0    0.333333    0.471420   0.000000   0.000000
#
#                                50%         75%         max
# Pregnancies               2.000000    6.000000   14.000000
# PlasmaGlucose           104.000000  129.000000  192.000000
# DiastolicBloodPressure   72.000000   85.000000  117.000000
# TricepsThickness         31.000000   41.000000   93.000000
# SerumInsulin             83.000000  195.000000  799.000000
# BMI                      31.767940   39.259692   56.034628
# DiabetesPedigree          0.200297    0.616285    2.301594
# Age                      24.000000   35.000000   77.000000
# Diabetic                  0.000000    1.000000    1.000000

# %%
#Using Histogram to represent the statistical summary
#diabetes_data.hist(bins=10,figsize=(10,10))
#plt.show()

# %%
# Outcome countplot
sns.countplot(x = 'Diabetic',data = diabetes_data)

# %% [markdown]
# ## Part 3: Data Preprocessing

# %% [markdown]
# ###    A. Feature Selection

# %%
#Feature Selection using Chi-square method

from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

X = diabetes_data.iloc[:,0:8] 
y = diabetes_data.iloc[:,-1]   
imp_features = SelectKBest(score_func=chi2, k=8)
fit = imp_features.fit(X,y)
df_scores = pd.DataFrame(fit.scores_)
df_columns = pd.DataFrame(X.columns) 
attr_scores = pd.concat([df_columns,df_scores],axis=1)
attr_scores.columns = ['Features','Score']  
print(attr_scores.nlargest(8,'Score'))
# Out:
#                  Features          Score
# 4            SerumInsulin  117899.178047
# 0             Pregnancies    8873.960067
# 7                     Age    8538.278751
# 3        TricepsThickness    2565.049101
# 1           PlasmaGlucose    2330.615204
# 5                     BMI    2008.936371
# 2  DiastolicBloodPressure     493.109061
# 6        DiabetesPedigree     155.745810

# %%
#Feature Selection using Correlation Matrix
diabetes_data.corr()
# Out:
#                         Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# Pregnancies                1.000000       0.054502                0.043528
# PlasmaGlucose              0.054502       1.000000                0.007212
# DiastolicBloodPressure     0.043528       0.007212                1.000000
# TricepsThickness           0.063605       0.027100                0.011106
# SerumInsulin               0.104487       0.033545                0.022649
# BMI                        0.086386       0.020653                0.015873
# DiabetesPedigree           0.054240       0.009057                0.014099
# Age                        0.136972       0.038864                0.041333
# Diabetic                   0.407315       0.128004                0.091307
#
#                         TricepsThickness  SerumInsulin       BMI  \
# Pregnancies                     0.063605      0.104487  0.086386
# PlasmaGlucose                   0.027100      0.033545  0.020653
# DiastolicBloodPressure          0.011106      0.022649  0.015873
# TricepsThickness                1.000000      0.029688  0.024745
# SerumInsulin                    0.029688      1.000000  0.051223
# BMI                             0.024745      0.051223  1.000000
# DiabetesPedigree               -0.000951      0.046324  0.028868
# Age                             0.061383      0.088007  0.062910
# Diabetic                        0.152505      0.247375  0.210508
#
#                         DiabetesPedigree       Age  Diabetic
# Pregnancies                     0.054240  0.136972  0.407315
# PlasmaGlucose                   0.009057  0.038864  0.128004
# DiastolicBloodPressure          0.014099  0.041333  0.091307
# TricepsThickness               -0.000951  0.061383  0.152505
# SerumInsulin                    0.046324  0.088007  0.247375
# BMI                             0.028868  0.062910  0.210508
# DiabetesPedigree                1.000000  0.055633  0.170302
# Age                             0.055633  1.000000  0.342605
# Diabetic                        0.170302  0.342605  1.000000

# %%
#Using Heatmap to visualize the correlation matrix

fig, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(diabetes_data.corr(), vmax=1, annot=True,square=True);
plt.show()

# %%
#Using RandomForest classifier for feature selection

from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X,y)
print(model.feature_importances_) 
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(8).plot(kind='barh')
plt.show()
# Out:
# [0.31765677 0.08439364 0.04726966 0.05562819 0.12876365 0.16937637
#  0.0435184  0.15339332]

# %%
# Feature scaling using MinMaxScaler
#from sklearn.preprocessing import MinMaxScaler
#scalar = MinMaxScaler(feature_range = (0, 1))
#diabetes_data_scaled = scalar.fit_transform(diabetes_data)

# %%
#diabetes_data_scaled = pd.DataFrame(diabetes_data_scaled)
#diabetes_data_scaled

# %%
# Selecting features - [Preganancies,Glucose, Insulin, BMI, Age]
X = diabetes_data.iloc[:, [0, 1, 4, 5, 7]].values

#Labelled data
Y = diabetes_data.iloc[:, 8].values

# %% [markdown]
# ### B. Feature Scaling using MinMaxScalar

# %%
# Feature scaling using MinMaxScaler

from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler(feature_range = (0, 1))
scalar.fit_transform(X)
X
# Out:
# array([[  0.        , 171.        ,  23.        ,  43.50972593,
#          21.        ],
#        [  8.        ,  92.        ,  36.        ,  21.24057571,
#          23.        ],
#        [  7.        , 115.        ,  35.        ,  41.51152348,
#          23.        ],
#        ...,
#        [  0.        ,  93.        ,  57.        ,  18.69068305,
#          24.        ],
#        [  0.        , 132.        , 161.        ,  19.7916451 ,
#          23.        ],
#        [  3.        , 114.        , 512.        ,  36.21543653,
#          34.        ]])

# %%
#Setting the seed value

seed = 5
np.random.seed(seed)

# %%
#Splitting the data into train data and test data

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=seed)

# %%
# Checking the count of 0 and 1 by plotting the countplot

sns.countplot(x = 'Diabetic',data = diabetes_data)

# %%
#Using the SMOTE library for balancing the outcome.

from imblearn.over_sampling import SMOTE

# transform the dataset
smote = SMOTE(random_state=2)
X_train_smote, y_train_smote = smote.fit_sample(X_train, y_train)

# %%
#Before Oversampling - Checking the shape of data and count of outcome

print("The shape of X_train before oversampling = {}".format(X_train.shape))
print("The shape of Y_train before oversampling = {}".format(y_train.shape))

print("The count of label 0 before oversampling = {}".format(sum(y_train == 0)))
print("The count of label 1 before oversampling = {}".format(sum(y_train == 1)))

#After Oversampling - Checking the shape of data and count of outcome
  
print("The shape of X_train_smote after oversampling = {}".format(X_train_smote.shape))
print("The shape of Y_train before oversampling = {}".format(y_train_smote.shape))

print("The count of label 0 before after oversampling = {}".format(sum(y_train_smote == 0)))
print("The count of label 1 before after oversampling = {}".format(sum(y_train_smote == 1)))
# Out:
# The shape of X_train before oversampling = (10500, 5)
# The shape of Y_train before oversampling = (10500,)
# The count of label 0 before oversampling = 7014
# The count of label 1 before oversampling = 3486
# The shape of X_train_smote after oversampling = (14028, 5)
# The shape of Y_train before oversampling = (14028,)
# The count of label 0 before after oversampling = 7014
# The count of label 1 before after oversampling = 7014

# %% [markdown]
# # Part 4: Parameter Optimization

# %%
# Importing required sklearn and keras packages
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV, KFold
# Out:
# Using TensorFlow backend.
# C:\Users\Ruchira\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Ruchira\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Ruchira\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Ruchira\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Ruchira\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Ruchira\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Ruchira\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Ruchira\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Ruchira\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Ruchira\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Ruchira\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Ruchira\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### 1. Tuning Batch Size and Number of Epochs

# %%
# Creating the model
def define_model():
    model = Sequential()
    model.add(Dense(10, input_dim = 5, activation='relu')) 
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    return model

#Checking the summary of model
model = define_model()
print(model.summary())
# Out:
# WARNING:tensorflow:From C:\Users\Ruchira\anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                60
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 71
# Trainable params: 71
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Model Initialization with Keras Classifier
model = KerasClassifier(build_fn=define_model,verbose=0)

# %%
# Defining the batch size and number of epochs

batch_size = [50, 100, 150, 200, 250, 300] 
epochs = [200, 400, 600, 800, 1000]

# %%
# Creating a dictionay of the grid search paramters (batch size and epochs)
param_grid = {'batch_size':batch_size,'epochs':epochs}

# %%
# Buidling the grid using GridSearchCV
grid = GridSearchCV(estimator=model,param_grid = param_grid, cv= 5, verbose=10, return_train_score=True, n_jobs=-1)

#Fitting the grid
grid_search = grid.fit(X_train_smote,y_train_smote)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 15.5min
# C:\Users\Ruchira\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed: 21.7min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed: 23.2min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 24.8min finished
# WARNING:tensorflow:From C:\Users\Ruchira\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
# Summarizing the result - Best Accuracy using batch size and epochs
print("Best Accuracy: {0}, using {1}".format(grid_search.best_score_, grid_search.best_params_))
# Out:
# Best Accuracy: 0.8609247446060181, using {'batch_size': 50, 'epochs': 800}

# %%
# finding the mean train accuracy, mean test accuracy and standard deviation
means_train = grid_search.cv_results_['mean_train_score']
means_test = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean_train,mean_test, stdev, param in zip(means_train,means_test, stds, params):
    print('{0} {1} ({2}) with: {3}'.format(mean_train,mean_test, stdev, param))
# Out:
# 0.8324780344963074 0.8053141593933105 (0.0451107865684758) with: {'batch_size': 50, 'epochs': 200}
# 0.8273995995521546 0.7735853433609009 (0.10365952763638929) with: {'batch_size': 50, 'epochs': 400}
# 0.8374857306480408 0.806456458568573 (0.057585761831308827) with: {'batch_size': 50, 'epochs': 600}
# 0.8693859219551087 0.8609247446060181 (0.033253441176752344) with: {'batch_size': 50, 'epochs': 800}
# 0.8692795872688294 0.8534358382225037 (0.018410870583746918) with: {'batch_size': 50, 'epochs': 1000}
# 0.8052647709846497 0.7713114500045777 (0.0443538159955809) with: {'batch_size': 100, 'epochs': 200}
# 0.8106284260749816 0.7902057290077209 (0.011986783118855305) with: {'batch_size': 100, 'epochs': 400}
# 0.872042441368103 0.8522230744361877 (0.01923412617982181) with: {'batch_size': 100, 'epochs': 600}
# 0.8324946284294128 0.8220785856246948 (0.049876847248419974) with: {'batch_size': 100, 'epochs': 800}
# 0.8586940288543701 0.83603835105896 (0.05011338120571865) with: {'batch_size': 100, 'epochs': 1000}
# 0.8154230952262879 0.7996123671531677 (0.030317952144369085) with: {'batch_size': 150, 'epochs': 200}
# 0.828290319442749 0.8121602654457092 (0.032712075961968665) with: {'batch_size': 150, 'epochs': 400}
# 0.8103250861167908 0.791273319721222 (0.05434661759832295) with: {'batch_size': 150, 'epochs': 600}
# 0.8385714888572693 0.8274220824241638 (0.04747574623483766) with: {'batch_size': 150, 'epochs': 800}
# 0.8261882543563843 0.7771488904953003 (0.0928804971038426) with: {'batch_size': 150, 'epochs': 1000}
# 0.8460595369338989 0.8166458964347839 (0.03970087892212855) with: {'batch_size': 200, 'epochs': 200}
# 0.7999003052711486 0.7684601902961731 (0.04140185542637127) with: {'batch_size': 200, 'epochs': 400}
# 0.839161491394043 0.81636643409729 (0.053042760015965154) with: {'batch_size': 200, 'epochs': 600}
# 0.8591201782226563 0.8493795275688172 (0.04283361686990857) with: {'batch_size': 200, 'epochs': 800}
# 0.8345454096794128 0.7820698976516723 (0.1082223632957108) with: {'batch_size': 200, 'epochs': 1000}
# 0.811074948310852 0.7840713500976563 (0.03290593106519862) with: {'batch_size': 250, 'epochs': 200}
# 0.8040530204772949 0.7646062731742859 (0.07612267814794342) with: {'batch_size': 250, 'epochs': 400}
# 0.8272930145263672 0.80973219871521 (0.040637968742892466) with: {'batch_size': 250, 'epochs': 600}
# 0.8523845791816711 0.8292007684707642 (0.021679388662627867) with: {'batch_size': 250, 'epochs': 800}
# 0.8476786613464355 0.8480972170829773 (0.04759257222016384) with: {'batch_size': 250, 'epochs': 1000}
# 0.8008629441261291 0.7713101029396057 (0.0436118635360985) with: {'batch_size': 300, 'epochs': 200}
# 0.8270587205886841 0.818370008468628 (0.04200825741997005) with: {'batch_size': 300, 'epochs': 400}
# 0.8129646182060242 0.7644612073898316 (0.07048162230748312) with: {'batch_size': 300, 'epochs': 600}
# 0.8029295921325683 0.7613316297531127 (0.06260981903315055) with: {'batch_size': 300, 'epochs': 800}
# 0.8467357277870178 0.8106590986251831 (0.07262776500595874) with: {'batch_size': 300, 'epochs': 1000}

# %% [markdown]
# ### 2. Tuning Optimization Algorithm

# %%
# Creating the model
def define_model(optimizer = 'adam'):
    model = Sequential()
    model.add(Dense(10, input_dim = 5, activation= 'relu'))
    model.add(Dense(1, activation='sigmoid'))
    
    #compile the model
    model.compile(loss = 'binary_crossentropy', optimizer = optimizer, metrics = ['accuracy'])
    return model

# Model Initialization by Keras Classifier
model = KerasClassifier(build_fn = define_model, epochs = 800, batch_size = 50, verbose = 0)

# Defining the grid search parameter - optimizer
optimizer = ['Adam', 'Adadelta', 'Adamax', 'Adagrad', 'SGD', 'RMSprop']

# Creating a dictionary of grid search parameter
param_grid = {'optimizer' : optimizer}

# Building the grid using GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = 5, verbose = 10, return_train_score=True, n_jobs=-1)

# Fitting the grid
grid_search = grid.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  19 out of  30 | elapsed:  9.1min remaining:  5.2min
# [Parallel(n_jobs=-1)]: Done  23 out of  30 | elapsed:  9.1min remaining:  2.8min
# [Parallel(n_jobs=-1)]: Done  27 out of  30 | elapsed: 11.7min remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed: 11.7min finished

# %%
# Summarizing the result - Best Accuracy using optimizer
print("Best Accuracy: {0}, using {1}".format(grid_search.best_score_, grid_search.best_params_))
# Out:
# Best Accuracy: 0.8758923768997192, using {'optimizer': 'Adam'}

# %%
# finding the mean train accuracy, mean test accuracy and standard deviation
means_train = grid_search.cv_results_['mean_train_score']
means_test = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean_train,mean_test, stdev, param in zip(means_train,means_test, stds, params):
    print('{0} {1} ({2}) with: {3}'.format(mean_train,mean_test, stdev, param))
# Out:
# 0.8829488635063172 0.8758923768997192 (0.00977940450125533) with: {'optimizer': 'Adam'}
# 0.8819324851036072 0.8718293309211731 (0.01964630742926397) with: {'optimizer': 'Adadelta'}
# 0.8551291584968567 0.8277724862098694 (0.036372153865843936) with: {'optimizer': 'Adamax'}
# 0.7816328287124634 0.7414438009262085 (0.04155701496867145) with: {'optimizer': 'Adagrad'}
# 0.7972105503082275 0.7777220726013183 (0.05244766647497512) with: {'optimizer': 'SGD'}
# 0.8847127676010131 0.8729007482528687 (0.024457266789138146) with: {'optimizer': 'RMSprop'}

# %% [markdown]
# ### 3. Tuning Learning Rate

# %%
from keras.optimizers import Adam

# Creating the model
def define_model(lr = 0.01):
    model = Sequential()
    model.add(Dense(10,input_dim = 5, activation= 'relu'))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    adam = Adam(lr = lr)
    model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
    return model

# Model Initialization using Keras Classifier
model = KerasClassifier(build_fn = define_model, epochs = 800, batch_size =50,verbose=0)

# Defining the grid search parameter - learning rate
lr = [0.001, 0.01, 0.1]

# Creating a dictionay of the grid search parameter - learning rate
param_grid = dict(lr = lr)

# Building the grid using GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, verbose = 10, return_train_score=True, n_jobs = -1, cv=5)

#Fitting the grid
grid_search = grid.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  15 | elapsed:  3.3min remaining: 21.6min
# [Parallel(n_jobs=-1)]: Done   4 out of  15 | elapsed:  3.3min remaining:  9.2min
# [Parallel(n_jobs=-1)]: Done   6 out of  15 | elapsed:  3.3min remaining:  5.0min
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:  3.3min remaining:  2.9min
# [Parallel(n_jobs=-1)]: Done  10 out of  15 | elapsed:  6.6min remaining:  3.3min
# [Parallel(n_jobs=-1)]: Done  12 out of  15 | elapsed:  6.6min remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:  6.6min finished

# %%
#Finding best accuracy using learning rate
print("Best Accuracy: {0}, using {1}".format(grid_search.best_score_, grid_search.best_params_))
# Out:
# Best Accuracy: 0.8471689224243164, using {'lr': 0.001}

# %%
#Summarize the results - mean train accuracy, mean test accuracy, standard deviation

means_train = grid_search.cv_results_['mean_train_score']
means_test = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean_train,mean_test, stdev, param in zip(means_train,means_test, stds, params):
    print('{0} {1} ({2}) with: {3}'.format(mean_train,mean_test, stdev, param))
# Out:
# 0.8537563562393189 0.8471689224243164 (0.04836330903384387) with: {'lr': 0.001}
# 0.8592639923095703 0.8279143452644349 (0.025074653469596423) with: {'lr': 0.01}
# 0.5499888300895691 0.3000353217124939 (0.16255269139347506) with: {'lr': 0.1}

# %% [markdown]
# ### 4. Tuning Kernel Initializer

# %%
# Creating the model
def define_model(init='uniform'):
    model = Sequential()
    model.add(Dense(10, input_dim = 5, kernel_initializer= init, activation= 'relu'))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    return model

# Model Initialization using keras classifier
model = KerasClassifier(build_fn = define_model, epochs = 800, batch_size = 50, verbose=0)

# Defining the grid search parameter - kernel initializer
init = ['uniform', 'normal', 'zero']

# Creating a dictionary of grid search parameter
param_grid = dict(init = init)

# Building the grid using GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, verbose = 10, n_jobs = -1, return_train_score=True, cv = 5)

#Fitting the grid
grid_search = grid.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  15 | elapsed:  3.6min remaining: 23.6min
# [Parallel(n_jobs=-1)]: Done   4 out of  15 | elapsed:  3.7min remaining: 10.1min
# [Parallel(n_jobs=-1)]: Done   6 out of  15 | elapsed:  3.7min remaining:  5.5min
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:  3.7min remaining:  3.2min
# [Parallel(n_jobs=-1)]: Done  10 out of  15 | elapsed:  6.9min remaining:  3.4min
# [Parallel(n_jobs=-1)]: Done  12 out of  15 | elapsed:  7.0min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:  7.0min finished

# %%
#Finding best accuracy using best kernel initializer
print("Best Accuracy: {0}, using {1}".format(grid_search.best_score_, grid_search.best_params_))
# Out:
# Best Accuracy: 0.8660545945167542, using {'init': 'uniform'}

# %%
# Summarize the results - Mean train accuracy, Mean Test accuracy, standard deviation
means_train = grid_search.cv_results_['mean_train_score']
means_test = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean_train,mean_test, stdev, param in zip(means_train,means_test, stds, params):
    print('{0} {1} ({2}) with: {3}'.format(mean_train,mean_test, stdev, param))
# Out:
# 0.8798477053642273 0.8660545945167542 (0.01505414091690006) with: {'init': 'uniform'}
# 0.8744309782981873 0.8425215721130371 (0.0682346089104642) with: {'init': 'normal'}
# 0.5499888300895691 0.3000353217124939 (0.16255269139347506) with: {'init': 'zero'}

# %% [markdown]
# ### 5. Tuning Activation Function

# %%
#Creating the model
def define_model(activation='relu'):
    model = Sequential()
    model.add(Dense(10, input_dim = 5, kernel_initializer= 'uniform', activation= activation))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    return model

# Model Initialization using keras classifier
model = KerasClassifier(build_fn = define_model, epochs = 800, batch_size = 50, verbose=0)

# Define the activation function - grid search parameter
activation = ['softmax', 'relu', 'tanh', 'linear', 'sigmoid'] # most common activations

# Creating a dictionary of activation function - grid search parameter
param_grid = dict(activation = activation)

# Builing the grid using GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, verbose = 10, n_jobs = -1, return_train_score=True, cv = 5)

#Fitting the grid 
grid_search = grid.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done  13 out of  25 | elapsed:  7.4min remaining:  6.8min
# [Parallel(n_jobs=-1)]: Done  16 out of  25 | elapsed:  7.4min remaining:  4.2min
# [Parallel(n_jobs=-1)]: Done  19 out of  25 | elapsed: 11.4min remaining:  3.6min
# [Parallel(n_jobs=-1)]: Done  22 out of  25 | elapsed: 11.5min remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed: 12.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed: 12.7min finished

# %%
#Finding the best accuracy using best activation function
print("Best Accuracy: {0}, using {1}".format(grid_search.best_score_, grid_search.best_params_))
# Out:
# Best Accuracy: 0.8920037746429443, using {'activation': 'sigmoid'}

# %%
# Summarizing the result - mean train accuracy, mean test accuracy, standard deviation

means_train = grid_search.cv_results_['mean_train_score']
means_test = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean_train,mean_test, stdev, param in zip(means_train,means_test, stds, params):
    print('{0} {1} ({2}) with: {3}'.format(mean_train,mean_test, stdev, param))
# Out:
# 0.8741620779037476 0.866487181186676 (0.035465136006480096) with: {'activation': 'softmax'}
# 0.8825918674468994 0.8744701027870179 (0.029860805783817276) with: {'activation': 'relu'}
# 0.8922337651252746 0.8814510703086853 (0.007623671396843469) with: {'activation': 'tanh'}
# 0.7607288002967835 0.7142797589302063 (0.06660839143127936) with: {'activation': 'linear'}
# 0.9004312753677368 0.8920037746429443 (0.015835573286200985) with: {'activation': 'sigmoid'}

# %% [markdown]
# ### 6. Tuning Number of Neurons

# %%
# Creating the model
def define_model(neurons=1):
    model = Sequential()
    model.add(Dense(neurons, input_dim = 5, kernel_initializer= 'uniform', activation= 'sigmoid'))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    adam = Adam(lr = 0.1)
    model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
    return model

# Model Intialization using keras classifier
model = KerasClassifier(build_fn = define_model, epochs = 800, batch_size = 50, verbose = 0)

# Define the grid search parameter - number of neurons
neurons = [1, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]

# Creating a dictionary of the grid search parameter - number of neurons
param_grid = dict(neurons=neurons)

# Building the fit using GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = 5, verbose = 10, n_jobs = -1)

# Fitting the grid
grid_search = grid.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=-1)]: Done  46 out of  55 | elapsed: 25.8min remaining:  5.1min
# [Parallel(n_jobs=-1)]: Done  52 out of  55 | elapsed: 30.5min remaining:  1.8min
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed: 30.6min finished

# %%
# Finding best accuracy using best value of neurons
print("Best: {0}, using {1}".format(grid_search.best_score_, grid_search.best_params_))
# Out:
# Best: 0.764420998096466, using {'neurons': 50}

# %%
# Summarizing the result - mean train accuracy, mean test accuracy. standard deviation

means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('{0} ({1}) with: {2}'.format(mean, stdev, param))
# Out:
# 0.3000353217124939 (0.16255269139347506) with: {'neurons': 1}
# 0.764420998096466 (0.133560287285747) with: {'neurons': 50}
# 0.3000353217124939 (0.16255269139347506) with: {'neurons': 100}
# 0.30181785821914675 (0.1647212455059818) with: {'neurons': 150}
# 0.5643980383872986 (0.2495238319154228) with: {'neurons': 200}
# 0.30181785821914675 (0.1647212455059818) with: {'neurons': 250}
# 0.358553421497345 (0.2059093963348184) with: {'neurons': 300}
# 0.5841408133506775 (0.2597736558454178) with: {'neurons': 350}
# 0.4999646782875061 (0.2576999200509476) with: {'neurons': 400}
# 0.5000353217124939 (0.2576999200509476) with: {'neurons': 450}
# 0.37088350057601926 (0.22302058115426332) with: {'neurons': 500}

# %% [markdown]
# ## Part 5: Data Modelling using optimized parameters

# %%
#Creating the model
from keras.optimizers import Adam

model = Sequential()
model.add(Dense(50, input_dim = 5, kernel_initializer = 'uniform', activation = 'sigmoid'))
model.add(Dense(1, activation='sigmoid'))
    
# compile the model
adam = Adam(lr = 0.001)
model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
 
#Fitting the model
history = model.fit(X_train_smote, y_train_smote, validation_data = (X_test,y_test), epochs = 800, batch_size = 50)
# Out:
# WARNING:tensorflow:From C:\Users\Ruchira\anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\Ruchira\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 14028 samples, validate on 4500 samples
# Epoch 1/800
# 14028/14028 [==============================] - 0s 28us/step - loss: 0.5687 - accuracy: 0.7176 - val_loss: 0.5072 - val_accuracy: 0.7649
# Epoch 2/800
# 14028/14028 [==============================] - 0s 20us/step - loss: 0.4982 - accuracy: 0.7849 - val_loss: 0.4832 - val_accuracy: 0.7844
# Epoch 3/800
# 14028/14028 [==============================] - 0s 20us/step - loss: 0.4574 - accuracy: 0.8082 - val_loss: 0.4605 - val_accuracy: 0.7911
# Epoch 4/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.4200 - accuracy: 0.8296 - val_loss: 0.3926 - val_accuracy: 0.8189
# Epoch 5/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.3862 - accuracy: 0.8414 - val_loss: 0.3655 - val_accuracy: 0.8311
# Epoch 6/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.3568 - accuracy: 0.8530 - val_loss: 0.3386 - val_accuracy: 0.8440
# Epoch 7/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.3445 - accuracy: 0.8576 - val_loss: 0.3873 - val_accuracy: 0.8282
# Epoch 8/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.3365 - accuracy: 0.8599 - val_loss: 0.3322 - val_accuracy: 0.8411
# Epoch 9/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.3299 - accuracy: 0.8641 - val_loss: 0.4164 - val_accuracy: 0.7982
# Epoch 10/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.3266 - accuracy: 0.8656 - val_loss: 0.3213 - val_accuracy: 0.8640
# Epoch 11/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.3188 - accuracy: 0.8693 - val_loss: 0.3148 - val_accuracy: 0.8638
# Epoch 12/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.3155 - accuracy: 0.8703 - val_loss: 0.3235 - val_accuracy: 0.8560
# Epoch 13/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.3136 - accuracy: 0.8681 - val_loss: 0.3471 - val_accuracy: 0.8493
# Epoch 14/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.3119 - accuracy: 0.8729 - val_loss: 0.3137 - val_accuracy: 0.8611
# Epoch 15/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.3077 - accuracy: 0.8740 - val_loss: 0.3117 - val_accuracy: 0.8629
# Epoch 16/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.3094 - accuracy: 0.8718 - val_loss: 0.3285 - val_accuracy: 0.8520
# Epoch 17/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.3034 - accuracy: 0.8758 - val_loss: 0.3160 - val_accuracy: 0.8640
# Epoch 18/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.3027 - accuracy: 0.8745 - val_loss: 0.3280 - val_accuracy: 0.8558
# Epoch 19/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.3009 - accuracy: 0.8777 - val_loss: 0.2985 - val_accuracy: 0.8729
# Epoch 20/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2998 - accuracy: 0.8752 - val_loss: 0.3003 - val_accuracy: 0.8709
# Epoch 21/800
# 14028/14028 [==============================] - 0s 17us/step - loss: 0.2971 - accuracy: 0.8798 - val_loss: 0.3093 - val_accuracy: 0.8669
# Epoch 22/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2972 - accuracy: 0.8785 - val_loss: 0.2904 - val_accuracy: 0.8747
# Epoch 23/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2939 - accuracy: 0.8800 - val_loss: 0.2956 - val_accuracy: 0.8764
# Epoch 24/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2949 - accuracy: 0.8810 - val_loss: 0.2952 - val_accuracy: 0.8756
# Epoch 25/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2915 - accuracy: 0.8812 - val_loss: 0.3013 - val_accuracy: 0.8722
# Epoch 26/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2890 - accuracy: 0.8819 - val_loss: 0.2943 - val_accuracy: 0.8782
# Epoch 27/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2906 - accuracy: 0.8806 - val_loss: 0.2896 - val_accuracy: 0.8747
# Epoch 28/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2881 - accuracy: 0.8822 - val_loss: 0.3048 - val_accuracy: 0.8656
# Epoch 29/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2871 - accuracy: 0.8837 - val_loss: 0.2833 - val_accuracy: 0.8820
# Epoch 30/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2854 - accuracy: 0.8836 - val_loss: 0.3100 - val_accuracy: 0.8638
# Epoch 31/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2852 - accuracy: 0.8837 - val_loss: 0.2921 - val_accuracy: 0.8771
# Epoch 32/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2834 - accuracy: 0.8848 - val_loss: 0.3092 - val_accuracy: 0.8689
# Epoch 33/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2870 - accuracy: 0.8834 - val_loss: 0.2865 - val_accuracy: 0.8776
# Epoch 34/800
# 14028/14028 [==============================] - 0s 20us/step - loss: 0.2814 - accuracy: 0.8864 - val_loss: 0.3016 - val_accuracy: 0.8724
# Epoch 35/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2830 - accuracy: 0.8862 - val_loss: 0.2982 - val_accuracy: 0.8713
# Epoch 36/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2805 - accuracy: 0.8870 - val_loss: 0.2822 - val_accuracy: 0.8849
# Epoch 37/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2791 - accuracy: 0.8896 - val_loss: 0.2820 - val_accuracy: 0.8818
# Epoch 38/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2798 - accuracy: 0.8882 - val_loss: 0.2956 - val_accuracy: 0.8793
# Epoch 39/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2796 - accuracy: 0.8864 - val_loss: 0.2791 - val_accuracy: 0.8829
# Epoch 40/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2780 - accuracy: 0.8896 - val_loss: 0.2873 - val_accuracy: 0.8780
# Epoch 41/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2772 - accuracy: 0.8881 - val_loss: 0.2862 - val_accuracy: 0.8818
# Epoch 42/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2769 - accuracy: 0.8874 - val_loss: 0.2940 - val_accuracy: 0.8811
# Epoch 43/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2768 - accuracy: 0.8898 - val_loss: 0.2833 - val_accuracy: 0.8831
# Epoch 44/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2764 - accuracy: 0.8883 - val_loss: 0.2862 - val_accuracy: 0.8776
# Epoch 45/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2755 - accuracy: 0.8902 - val_loss: 0.2690 - val_accuracy: 0.8920
# Epoch 46/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2749 - accuracy: 0.8913 - val_loss: 0.2706 - val_accuracy: 0.8896
# Epoch 47/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2730 - accuracy: 0.8899 - val_loss: 0.2821 - val_accuracy: 0.8824
# Epoch 48/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2724 - accuracy: 0.8899 - val_loss: 0.2833 - val_accuracy: 0.8818
# Epoch 49/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2712 - accuracy: 0.8935 - val_loss: 0.3369 - val_accuracy: 0.8509
# Epoch 50/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2739 - accuracy: 0.8895 - val_loss: 0.2747 - val_accuracy: 0.8884
# Epoch 51/800
# 14028/14028 [==============================] - 0s 20us/step - loss: 0.2703 - accuracy: 0.8914 - val_loss: 0.2705 - val_accuracy: 0.8891
# Epoch 52/800
# 14028/14028 [==============================] - 0s 20us/step - loss: 0.2733 - accuracy: 0.8921 - val_loss: 0.3300 - val_accuracy: 0.8580
# Epoch 53/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2708 - accuracy: 0.8938 - val_loss: 0.2767 - val_accuracy: 0.8851
# Epoch 54/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2698 - accuracy: 0.8919 - val_loss: 0.2690 - val_accuracy: 0.8873
# Epoch 55/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2691 - accuracy: 0.8936 - val_loss: 0.2837 - val_accuracy: 0.8802
# Epoch 56/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2726 - accuracy: 0.8913 - val_loss: 0.2770 - val_accuracy: 0.8882
# Epoch 57/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2693 - accuracy: 0.8922 - val_loss: 0.2784 - val_accuracy: 0.8847
# Epoch 58/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2677 - accuracy: 0.8926 - val_loss: 0.2915 - val_accuracy: 0.8824
# Epoch 59/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2680 - accuracy: 0.8949 - val_loss: 0.2638 - val_accuracy: 0.8922
# Epoch 60/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2684 - accuracy: 0.8916 - val_loss: 0.2912 - val_accuracy: 0.8744
# Epoch 61/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2673 - accuracy: 0.8938 - val_loss: 0.2727 - val_accuracy: 0.8911
# Epoch 62/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2683 - accuracy: 0.8910 - val_loss: 0.2840 - val_accuracy: 0.8796
# Epoch 63/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2705 - accuracy: 0.8903 - val_loss: 0.2922 - val_accuracy: 0.8813
# Epoch 64/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2659 - accuracy: 0.8948 - val_loss: 0.2704 - val_accuracy: 0.8891
# Epoch 65/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2671 - accuracy: 0.8934 - val_loss: 0.2742 - val_accuracy: 0.8884
# Epoch 66/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2670 - accuracy: 0.8935 - val_loss: 0.2657 - val_accuracy: 0.8871
# Epoch 67/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2687 - accuracy: 0.8923 - val_loss: 0.2746 - val_accuracy: 0.8902
# Epoch 68/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2646 - accuracy: 0.8939 - val_loss: 0.2659 - val_accuracy: 0.8902
# Epoch 69/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2656 - accuracy: 0.8944 - val_loss: 0.2643 - val_accuracy: 0.8918
# Epoch 70/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2645 - accuracy: 0.8946 - val_loss: 0.2707 - val_accuracy: 0.8873
# Epoch 71/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2645 - accuracy: 0.8962 - val_loss: 0.2715 - val_accuracy: 0.8860
# Epoch 72/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2658 - accuracy: 0.8942 - val_loss: 0.2731 - val_accuracy: 0.8891
# Epoch 73/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2653 - accuracy: 0.8939 - val_loss: 0.2775 - val_accuracy: 0.8891
# Epoch 74/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2642 - accuracy: 0.8948 - val_loss: 0.2650 - val_accuracy: 0.8918
# Epoch 75/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2639 - accuracy: 0.8950 - val_loss: 0.2669 - val_accuracy: 0.8884
# Epoch 76/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2616 - accuracy: 0.8944 - val_loss: 0.2920 - val_accuracy: 0.8822
# Epoch 77/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2635 - accuracy: 0.8939 - val_loss: 0.2864 - val_accuracy: 0.8784
# Epoch 78/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2624 - accuracy: 0.8956 - val_loss: 0.2767 - val_accuracy: 0.8873
# Epoch 79/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2619 - accuracy: 0.8966 - val_loss: 0.2784 - val_accuracy: 0.8822
# Epoch 80/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2618 - accuracy: 0.8961 - val_loss: 0.2687 - val_accuracy: 0.8900
# Epoch 81/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2629 - accuracy: 0.8948 - val_loss: 0.2580 - val_accuracy: 0.8931
# Epoch 82/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2620 - accuracy: 0.8956 - val_loss: 0.2808 - val_accuracy: 0.8818
# Epoch 83/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2620 - accuracy: 0.8955 - val_loss: 0.2681 - val_accuracy: 0.8936
# Epoch 84/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2594 - accuracy: 0.8975 - val_loss: 0.2729 - val_accuracy: 0.8876
# Epoch 85/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2583 - accuracy: 0.8981 - val_loss: 0.2859 - val_accuracy: 0.8793
# Epoch 86/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2619 - accuracy: 0.8946 - val_loss: 0.2599 - val_accuracy: 0.8931
# Epoch 87/800
# 14028/14028 [==============================] - ETA: 0s - loss: 0.2590 - accuracy: 0.89 - 0s 17us/step - loss: 0.2596 - accuracy: 0.8973 - val_loss: 0.2678 - val_accuracy: 0.8876
# Epoch 88/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2595 - accuracy: 0.8974 - val_loss: 0.2639 - val_accuracy: 0.8920
# Epoch 89/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2593 - accuracy: 0.8951 - val_loss: 0.2660 - val_accuracy: 0.8907
# Epoch 90/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2593 - accuracy: 0.8976 - val_loss: 0.2778 - val_accuracy: 0.8873
# Epoch 91/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2588 - accuracy: 0.8960 - val_loss: 0.2750 - val_accuracy: 0.8871
# Epoch 92/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2572 - accuracy: 0.8968 - val_loss: 0.3049 - val_accuracy: 0.8716
# Epoch 93/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2576 - accuracy: 0.8983 - val_loss: 0.2850 - val_accuracy: 0.8822
# Epoch 94/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2599 - accuracy: 0.8951 - val_loss: 0.2751 - val_accuracy: 0.8871
# Epoch 95/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2563 - accuracy: 0.8972 - val_loss: 0.2587 - val_accuracy: 0.8942
# Epoch 96/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2565 - accuracy: 0.8987 - val_loss: 0.2639 - val_accuracy: 0.8927
# Epoch 97/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2565 - accuracy: 0.8976 - val_loss: 0.2586 - val_accuracy: 0.8942
# Epoch 98/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2554 - accuracy: 0.8989 - val_loss: 0.2757 - val_accuracy: 0.8887
# Epoch 99/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2572 - accuracy: 0.8976 - val_loss: 0.2835 - val_accuracy: 0.8844
# Epoch 100/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2593 - accuracy: 0.8971 - val_loss: 0.2723 - val_accuracy: 0.8904
# Epoch 101/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2567 - accuracy: 0.8990 - val_loss: 0.3194 - val_accuracy: 0.8662
# Epoch 102/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2562 - accuracy: 0.8986 - val_loss: 0.2809 - val_accuracy: 0.8844
# Epoch 103/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2553 - accuracy: 0.8986 - val_loss: 0.2699 - val_accuracy: 0.8869
# Epoch 104/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2553 - accuracy: 0.8969 - val_loss: 0.2665 - val_accuracy: 0.8907
# Epoch 105/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2552 - accuracy: 0.8973 - val_loss: 0.2711 - val_accuracy: 0.8898
# Epoch 106/800
# 14028/14028 [==============================] - 0s 17us/step - loss: 0.2535 - accuracy: 0.9001 - val_loss: 0.2800 - val_accuracy: 0.8842
# Epoch 107/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2552 - accuracy: 0.8996 - val_loss: 0.2937 - val_accuracy: 0.8798
# Epoch 108/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2545 - accuracy: 0.8998 - val_loss: 0.2675 - val_accuracy: 0.8933
# Epoch 109/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2542 - accuracy: 0.8970 - val_loss: 0.2595 - val_accuracy: 0.8951
# Epoch 110/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2521 - accuracy: 0.9011 - val_loss: 0.2741 - val_accuracy: 0.8873
# Epoch 111/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2516 - accuracy: 0.9003 - val_loss: 0.2565 - val_accuracy: 0.8951
# Epoch 112/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2528 - accuracy: 0.9010 - val_loss: 0.2814 - val_accuracy: 0.8844
# Epoch 113/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2505 - accuracy: 0.9022 - val_loss: 0.2631 - val_accuracy: 0.8929
# Epoch 114/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2522 - accuracy: 0.9015 - val_loss: 0.2803 - val_accuracy: 0.8840
# Epoch 115/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2525 - accuracy: 0.9018 - val_loss: 0.2595 - val_accuracy: 0.8953
# Epoch 116/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2511 - accuracy: 0.8998 - val_loss: 0.2538 - val_accuracy: 0.8953
# Epoch 117/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2532 - accuracy: 0.8996 - val_loss: 0.2726 - val_accuracy: 0.8882
# Epoch 118/800
# 14028/14028 [==============================] - 0s 17us/step - loss: 0.2512 - accuracy: 0.9009 - val_loss: 0.2592 - val_accuracy: 0.8942
# Epoch 119/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2538 - accuracy: 0.8991 - val_loss: 0.2647 - val_accuracy: 0.8909
# Epoch 120/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2504 - accuracy: 0.9011 - val_loss: 0.2625 - val_accuracy: 0.8933
# Epoch 121/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2520 - accuracy: 0.9018 - val_loss: 0.2691 - val_accuracy: 0.8918
# Epoch 122/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2497 - accuracy: 0.9023 - val_loss: 0.2670 - val_accuracy: 0.8904
# Epoch 123/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2502 - accuracy: 0.9011 - val_loss: 0.2584 - val_accuracy: 0.8940
# Epoch 124/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2507 - accuracy: 0.9008 - val_loss: 0.2553 - val_accuracy: 0.8969
# Epoch 125/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2498 - accuracy: 0.9008 - val_loss: 0.2606 - val_accuracy: 0.8949
# Epoch 126/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2503 - accuracy: 0.9011 - val_loss: 0.2532 - val_accuracy: 0.8944
# Epoch 127/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2514 - accuracy: 0.9015 - val_loss: 0.2548 - val_accuracy: 0.8967
# Epoch 128/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2493 - accuracy: 0.9041 - val_loss: 0.2614 - val_accuracy: 0.8938
# Epoch 129/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2514 - accuracy: 0.9013 - val_loss: 0.2647 - val_accuracy: 0.8904
# Epoch 130/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2504 - accuracy: 0.9016 - val_loss: 0.2558 - val_accuracy: 0.8962
# Epoch 131/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2487 - accuracy: 0.9010 - val_loss: 0.2583 - val_accuracy: 0.8953
# Epoch 132/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2495 - accuracy: 0.9027 - val_loss: 0.2981 - val_accuracy: 0.8780
# Epoch 133/800
# 14028/14028 [==============================] - 0s 17us/step - loss: 0.2499 - accuracy: 0.9017 - val_loss: 0.2765 - val_accuracy: 0.8824
# Epoch 134/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2465 - accuracy: 0.9015 - val_loss: 0.2730 - val_accuracy: 0.8858
# Epoch 135/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2492 - accuracy: 0.9012 - val_loss: 0.2846 - val_accuracy: 0.8844
# Epoch 136/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2477 - accuracy: 0.9021 - val_loss: 0.2717 - val_accuracy: 0.8887
# Epoch 137/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2476 - accuracy: 0.9013 - val_loss: 0.2526 - val_accuracy: 0.8956
# Epoch 138/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2473 - accuracy: 0.9013 - val_loss: 0.2601 - val_accuracy: 0.8949
# Epoch 139/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2471 - accuracy: 0.9031 - val_loss: 0.2702 - val_accuracy: 0.8882
# Epoch 140/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2486 - accuracy: 0.9026 - val_loss: 0.2575 - val_accuracy: 0.8969
# Epoch 141/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2486 - accuracy: 0.9018 - val_loss: 0.2662 - val_accuracy: 0.8904
# Epoch 142/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2473 - accuracy: 0.9018 - val_loss: 0.2654 - val_accuracy: 0.8922
# Epoch 143/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2479 - accuracy: 0.9031 - val_loss: 0.2559 - val_accuracy: 0.8911
# Epoch 144/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2458 - accuracy: 0.9016 - val_loss: 0.2743 - val_accuracy: 0.8898
# Epoch 145/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2506 - accuracy: 0.8998 - val_loss: 0.2574 - val_accuracy: 0.8947
# Epoch 146/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2479 - accuracy: 0.9013 - val_loss: 0.2641 - val_accuracy: 0.8898
# Epoch 147/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2456 - accuracy: 0.9023 - val_loss: 0.2629 - val_accuracy: 0.8942
# Epoch 148/800
# 14028/14028 [==============================] - 0s 17us/step - loss: 0.2463 - accuracy: 0.9023 - val_loss: 0.2570 - val_accuracy: 0.8942
# Epoch 149/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2488 - accuracy: 0.9017 - val_loss: 0.2625 - val_accuracy: 0.8953
# Epoch 150/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2466 - accuracy: 0.9016 - val_loss: 0.2501 - val_accuracy: 0.8949
# Epoch 151/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2467 - accuracy: 0.9038 - val_loss: 0.2674 - val_accuracy: 0.8882
# Epoch 152/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2442 - accuracy: 0.9037 - val_loss: 0.2639 - val_accuracy: 0.8929
# Epoch 153/800
# 14028/14028 [==============================] - 0s 17us/step - loss: 0.2440 - accuracy: 0.9035 - val_loss: 0.2773 - val_accuracy: 0.8869
# Epoch 154/800
# 14028/14028 [==============================] - 0s 17us/step - loss: 0.2454 - accuracy: 0.9016 - val_loss: 0.2573 - val_accuracy: 0.8942
# Epoch 155/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2463 - accuracy: 0.9018 - val_loss: 0.2618 - val_accuracy: 0.8969
# Epoch 156/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2449 - accuracy: 0.9043 - val_loss: 0.2577 - val_accuracy: 0.8982
# Epoch 157/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2452 - accuracy: 0.9037 - val_loss: 0.2600 - val_accuracy: 0.8927
# Epoch 158/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2448 - accuracy: 0.9043 - val_loss: 0.2515 - val_accuracy: 0.8969
# Epoch 159/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2455 - accuracy: 0.9040 - val_loss: 0.2541 - val_accuracy: 0.8982
# Epoch 160/800
# 14028/14028 [==============================] - 0s 17us/step - loss: 0.2441 - accuracy: 0.9038 - val_loss: 0.2593 - val_accuracy: 0.8949
# Epoch 161/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2456 - accuracy: 0.9016 - val_loss: 0.2805 - val_accuracy: 0.8844
# Epoch 162/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2426 - accuracy: 0.9046 - val_loss: 0.2732 - val_accuracy: 0.8900
# Epoch 163/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2447 - accuracy: 0.9041 - val_loss: 0.2582 - val_accuracy: 0.8953
# Epoch 164/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2442 - accuracy: 0.9033 - val_loss: 0.2580 - val_accuracy: 0.8938
# Epoch 165/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2419 - accuracy: 0.9054 - val_loss: 0.2583 - val_accuracy: 0.8964
# Epoch 166/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2439 - accuracy: 0.9048 - val_loss: 0.2757 - val_accuracy: 0.8878
# Epoch 167/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2432 - accuracy: 0.9039 - val_loss: 0.2544 - val_accuracy: 0.8964
# Epoch 168/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2428 - accuracy: 0.9042 - val_loss: 0.2475 - val_accuracy: 0.8989
# Epoch 169/800
# 14028/14028 [==============================] - 0s 20us/step - loss: 0.2417 - accuracy: 0.9036 - val_loss: 0.2560 - val_accuracy: 0.8962
# Epoch 170/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2411 - accuracy: 0.9058 - val_loss: 0.2594 - val_accuracy: 0.8969
# Epoch 171/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2434 - accuracy: 0.9038 - val_loss: 0.2570 - val_accuracy: 0.8940
# Epoch 172/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2431 - accuracy: 0.9045 - val_loss: 0.2474 - val_accuracy: 0.8976
# Epoch 173/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2444 - accuracy: 0.9026 - val_loss: 0.2518 - val_accuracy: 0.8960
# Epoch 174/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2403 - accuracy: 0.9058 - val_loss: 0.2571 - val_accuracy: 0.8933
# Epoch 175/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2421 - accuracy: 0.9048 - val_loss: 0.2690 - val_accuracy: 0.8913
# Epoch 176/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2403 - accuracy: 0.9054 - val_loss: 0.2596 - val_accuracy: 0.8947
# Epoch 177/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2422 - accuracy: 0.9048 - val_loss: 0.2574 - val_accuracy: 0.8962
# Epoch 178/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2414 - accuracy: 0.9053 - val_loss: 0.2646 - val_accuracy: 0.8909
# Epoch 179/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2402 - accuracy: 0.9045 - val_loss: 0.2574 - val_accuracy: 0.8940
# Epoch 180/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2415 - accuracy: 0.9052 - val_loss: 0.2645 - val_accuracy: 0.8951
# Epoch 181/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2413 - accuracy: 0.9055 - val_loss: 0.2483 - val_accuracy: 0.9016
# Epoch 182/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2419 - accuracy: 0.9055 - val_loss: 0.2622 - val_accuracy: 0.8918
# Epoch 183/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2404 - accuracy: 0.9069 - val_loss: 0.2658 - val_accuracy: 0.8904
# Epoch 184/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2406 - accuracy: 0.9038 - val_loss: 0.2502 - val_accuracy: 0.8980
# Epoch 185/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2406 - accuracy: 0.9058 - val_loss: 0.2619 - val_accuracy: 0.8944
# Epoch 186/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2418 - accuracy: 0.9050 - val_loss: 0.2699 - val_accuracy: 0.8891
# Epoch 187/800
# 14028/14028 [==============================] - 0s 17us/step - loss: 0.2400 - accuracy: 0.9055 - val_loss: 0.2508 - val_accuracy: 0.8991
# Epoch 188/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2428 - accuracy: 0.9033 - val_loss: 0.2748 - val_accuracy: 0.8900
# Epoch 189/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2402 - accuracy: 0.9052 - val_loss: 0.2690 - val_accuracy: 0.8887
# Epoch 190/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2408 - accuracy: 0.9065 - val_loss: 0.2615 - val_accuracy: 0.8964
# Epoch 191/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2400 - accuracy: 0.9054 - val_loss: 0.2507 - val_accuracy: 0.8976
# Epoch 192/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2401 - accuracy: 0.9058 - val_loss: 0.2479 - val_accuracy: 0.9020
# Epoch 193/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2402 - accuracy: 0.9048 - val_loss: 0.2633 - val_accuracy: 0.8933
# Epoch 194/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2395 - accuracy: 0.9050 - val_loss: 0.2461 - val_accuracy: 0.9016
# Epoch 195/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2431 - accuracy: 0.9037 - val_loss: 0.2604 - val_accuracy: 0.8960
# Epoch 196/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2416 - accuracy: 0.9063 - val_loss: 0.2543 - val_accuracy: 0.8953
# Epoch 197/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2392 - accuracy: 0.9059 - val_loss: 0.2639 - val_accuracy: 0.8927
# Epoch 198/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2385 - accuracy: 0.9068 - val_loss: 0.2507 - val_accuracy: 0.8987
# Epoch 199/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2386 - accuracy: 0.9051 - val_loss: 0.2647 - val_accuracy: 0.8900
# Epoch 200/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2398 - accuracy: 0.9048 - val_loss: 0.2551 - val_accuracy: 0.8960
# Epoch 201/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2386 - accuracy: 0.9055 - val_loss: 0.2531 - val_accuracy: 0.8978
# Epoch 202/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2392 - accuracy: 0.9056 - val_loss: 0.2536 - val_accuracy: 0.8971
# Epoch 203/800
# 14028/14028 [==============================] - 0s 17us/step - loss: 0.2391 - accuracy: 0.9053 - val_loss: 0.2516 - val_accuracy: 0.9002
# Epoch 204/800
# 14028/14028 [==============================] - 0s 17us/step - loss: 0.2385 - accuracy: 0.9060 - val_loss: 0.2639 - val_accuracy: 0.8924
# Epoch 205/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2396 - accuracy: 0.9060 - val_loss: 0.2517 - val_accuracy: 0.8989
# Epoch 206/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2375 - accuracy: 0.9063 - val_loss: 0.2460 - val_accuracy: 0.9000
# Epoch 207/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2370 - accuracy: 0.9061 - val_loss: 0.2648 - val_accuracy: 0.8949
# Epoch 208/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2376 - accuracy: 0.9065 - val_loss: 0.2488 - val_accuracy: 0.9004
# Epoch 209/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2399 - accuracy: 0.9071 - val_loss: 0.2601 - val_accuracy: 0.8969
# Epoch 210/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2373 - accuracy: 0.9073 - val_loss: 0.2548 - val_accuracy: 0.8964
# Epoch 211/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2377 - accuracy: 0.9065 - val_loss: 0.2532 - val_accuracy: 0.8993
# Epoch 212/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2370 - accuracy: 0.9068 - val_loss: 0.2481 - val_accuracy: 0.8993
# Epoch 213/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2383 - accuracy: 0.9043 - val_loss: 0.2513 - val_accuracy: 0.8984
# Epoch 214/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2365 - accuracy: 0.9071 - val_loss: 0.2545 - val_accuracy: 0.8964
# Epoch 215/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2365 - accuracy: 0.9057 - val_loss: 0.2720 - val_accuracy: 0.8918
# Epoch 216/800
# 14028/14028 [==============================] - 0s 17us/step - loss: 0.2372 - accuracy: 0.9063 - val_loss: 0.2566 - val_accuracy: 0.8960
# Epoch 217/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2365 - accuracy: 0.9073 - val_loss: 0.2633 - val_accuracy: 0.8927
# Epoch 218/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2360 - accuracy: 0.9073 - val_loss: 0.2657 - val_accuracy: 0.8936
# Epoch 219/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2369 - accuracy: 0.9058 - val_loss: 0.2728 - val_accuracy: 0.8860
# Epoch 220/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2359 - accuracy: 0.9068 - val_loss: 0.2517 - val_accuracy: 0.8980
# Epoch 221/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2378 - accuracy: 0.9064 - val_loss: 0.2463 - val_accuracy: 0.8989
# Epoch 222/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2361 - accuracy: 0.9073 - val_loss: 0.2615 - val_accuracy: 0.8991
# Epoch 223/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2396 - accuracy: 0.9058 - val_loss: 0.2608 - val_accuracy: 0.8936
# Epoch 224/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2373 - accuracy: 0.9048 - val_loss: 0.2547 - val_accuracy: 0.8971
# Epoch 225/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2364 - accuracy: 0.9067 - val_loss: 0.2527 - val_accuracy: 0.8960
# Epoch 226/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2365 - accuracy: 0.9070 - val_loss: 0.2459 - val_accuracy: 0.9002
# Epoch 227/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2330 - accuracy: 0.9081 - val_loss: 0.2586 - val_accuracy: 0.8951
# Epoch 228/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2355 - accuracy: 0.9068 - val_loss: 0.2578 - val_accuracy: 0.8944
# Epoch 229/800
# 14028/14028 [==============================] - 0s 20us/step - loss: 0.2363 - accuracy: 0.9061 - val_loss: 0.2513 - val_accuracy: 0.8967
# Epoch 230/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2348 - accuracy: 0.9058 - val_loss: 0.2653 - val_accuracy: 0.8904
# Epoch 231/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2344 - accuracy: 0.9089 - val_loss: 0.2594 - val_accuracy: 0.8927
# Epoch 232/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2344 - accuracy: 0.9074 - val_loss: 0.2793 - val_accuracy: 0.8860
# Epoch 233/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2353 - accuracy: 0.9080 - val_loss: 0.2546 - val_accuracy: 0.8953
# Epoch 234/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2361 - accuracy: 0.9070 - val_loss: 0.2825 - val_accuracy: 0.8809
# Epoch 235/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2355 - accuracy: 0.9085 - val_loss: 0.2616 - val_accuracy: 0.8913
# Epoch 236/800
# 14028/14028 [==============================] - 0s 20us/step - loss: 0.2349 - accuracy: 0.9081 - val_loss: 0.2742 - val_accuracy: 0.8838
# Epoch 237/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2342 - accuracy: 0.9066 - val_loss: 0.2513 - val_accuracy: 0.8976
# Epoch 238/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2352 - accuracy: 0.9093 - val_loss: 0.2397 - val_accuracy: 0.9022
# Epoch 239/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2353 - accuracy: 0.9077 - val_loss: 0.2606 - val_accuracy: 0.8924
# Epoch 240/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2359 - accuracy: 0.9083 - val_loss: 0.2485 - val_accuracy: 0.9016
# Epoch 241/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2327 - accuracy: 0.9098 - val_loss: 0.2462 - val_accuracy: 0.9004
# Epoch 242/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2359 - accuracy: 0.9062 - val_loss: 0.2519 - val_accuracy: 0.9000
# Epoch 243/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2334 - accuracy: 0.9085 - val_loss: 0.2463 - val_accuracy: 0.9009
# Epoch 244/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2342 - accuracy: 0.9057 - val_loss: 0.2532 - val_accuracy: 0.8944
# Epoch 245/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2324 - accuracy: 0.9100 - val_loss: 0.2466 - val_accuracy: 0.9002
# Epoch 246/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2359 - accuracy: 0.9068 - val_loss: 0.2618 - val_accuracy: 0.8904
# Epoch 247/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2342 - accuracy: 0.9078 - val_loss: 0.2493 - val_accuracy: 0.8960
# Epoch 248/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2329 - accuracy: 0.9087 - val_loss: 0.2466 - val_accuracy: 0.8984
# Epoch 249/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2318 - accuracy: 0.9092 - val_loss: 0.2468 - val_accuracy: 0.8978
# Epoch 250/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2322 - accuracy: 0.9088 - val_loss: 0.2405 - val_accuracy: 0.9013
# Epoch 251/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2331 - accuracy: 0.9077 - val_loss: 0.2561 - val_accuracy: 0.9004
# Epoch 252/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2336 - accuracy: 0.9070 - val_loss: 0.2533 - val_accuracy: 0.8940
# Epoch 253/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2335 - accuracy: 0.9068 - val_loss: 0.2573 - val_accuracy: 0.8940
# Epoch 254/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2316 - accuracy: 0.9101 - val_loss: 0.2485 - val_accuracy: 0.8984
# Epoch 255/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2325 - accuracy: 0.9088 - val_loss: 0.2586 - val_accuracy: 0.8913
# Epoch 256/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2320 - accuracy: 0.9094 - val_loss: 0.2491 - val_accuracy: 0.8964
# Epoch 257/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2327 - accuracy: 0.9080 - val_loss: 0.2515 - val_accuracy: 0.8973
# Epoch 258/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2340 - accuracy: 0.9069 - val_loss: 0.2458 - val_accuracy: 0.8980
# Epoch 259/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2313 - accuracy: 0.9096 - val_loss: 0.2672 - val_accuracy: 0.8918
# Epoch 260/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2325 - accuracy: 0.9082 - val_loss: 0.2494 - val_accuracy: 0.8993
# Epoch 261/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2324 - accuracy: 0.9088 - val_loss: 0.2573 - val_accuracy: 0.8951
# Epoch 262/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2326 - accuracy: 0.9088 - val_loss: 0.2476 - val_accuracy: 0.8969
# Epoch 263/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2305 - accuracy: 0.9088 - val_loss: 0.2639 - val_accuracy: 0.8933
# Epoch 264/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2320 - accuracy: 0.9078 - val_loss: 0.2562 - val_accuracy: 0.8953
# Epoch 265/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2322 - accuracy: 0.9090 - val_loss: 0.2517 - val_accuracy: 0.8978
# Epoch 266/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2301 - accuracy: 0.9093 - val_loss: 0.2684 - val_accuracy: 0.8893
# Epoch 267/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2332 - accuracy: 0.9080 - val_loss: 0.2564 - val_accuracy: 0.8924
# Epoch 268/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2306 - accuracy: 0.9098 - val_loss: 0.2454 - val_accuracy: 0.8996
# Epoch 269/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2339 - accuracy: 0.9083 - val_loss: 0.2539 - val_accuracy: 0.8958
# Epoch 270/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2325 - accuracy: 0.9100 - val_loss: 0.2442 - val_accuracy: 0.9020
# Epoch 271/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2307 - accuracy: 0.9098 - val_loss: 0.2533 - val_accuracy: 0.8951
# Epoch 272/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2303 - accuracy: 0.9090 - val_loss: 0.2608 - val_accuracy: 0.8969
# Epoch 273/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2300 - accuracy: 0.9111 - val_loss: 0.2434 - val_accuracy: 0.9002
# Epoch 274/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2292 - accuracy: 0.9098 - val_loss: 0.2512 - val_accuracy: 0.8980
# Epoch 275/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2319 - accuracy: 0.9082 - val_loss: 0.2501 - val_accuracy: 0.8991
# Epoch 276/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2302 - accuracy: 0.9096 - val_loss: 0.2616 - val_accuracy: 0.8942
# Epoch 277/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2311 - accuracy: 0.9079 - val_loss: 0.2461 - val_accuracy: 0.8996
# Epoch 278/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2296 - accuracy: 0.9088 - val_loss: 0.2421 - val_accuracy: 0.9004
# Epoch 279/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2290 - accuracy: 0.9085 - val_loss: 0.2453 - val_accuracy: 0.8973
# Epoch 280/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2281 - accuracy: 0.9114 - val_loss: 0.2467 - val_accuracy: 0.8989
# Epoch 281/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2300 - accuracy: 0.9103 - val_loss: 0.2493 - val_accuracy: 0.8984
# Epoch 282/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2301 - accuracy: 0.9098 - val_loss: 0.2509 - val_accuracy: 0.8956
# Epoch 283/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2298 - accuracy: 0.9107 - val_loss: 0.2600 - val_accuracy: 0.8962
# Epoch 284/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2302 - accuracy: 0.9089 - val_loss: 0.2517 - val_accuracy: 0.8984
# Epoch 285/800
# 14028/14028 [==============================] - 0s 20us/step - loss: 0.2294 - accuracy: 0.9095 - val_loss: 0.2617 - val_accuracy: 0.8940
# Epoch 286/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2308 - accuracy: 0.9103 - val_loss: 0.2440 - val_accuracy: 0.9036
# Epoch 287/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2305 - accuracy: 0.9079 - val_loss: 0.2598 - val_accuracy: 0.8971
# Epoch 288/800
# 14028/14028 [==============================] - 0s 20us/step - loss: 0.2298 - accuracy: 0.9094 - val_loss: 0.2779 - val_accuracy: 0.8873
# Epoch 289/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2301 - accuracy: 0.9085 - val_loss: 0.2593 - val_accuracy: 0.8951
# Epoch 290/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2284 - accuracy: 0.9093 - val_loss: 0.2527 - val_accuracy: 0.8984
# Epoch 291/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2295 - accuracy: 0.9083 - val_loss: 0.2595 - val_accuracy: 0.8942
# Epoch 292/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2292 - accuracy: 0.9104 - val_loss: 0.2383 - val_accuracy: 0.9051
# Epoch 293/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2296 - accuracy: 0.9100 - val_loss: 0.2499 - val_accuracy: 0.9000
# Epoch 294/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2300 - accuracy: 0.9100 - val_loss: 0.2471 - val_accuracy: 0.8998
# Epoch 295/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2294 - accuracy: 0.9096 - val_loss: 0.2597 - val_accuracy: 0.8942
# Epoch 296/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2281 - accuracy: 0.9107 - val_loss: 0.2447 - val_accuracy: 0.9002
# Epoch 297/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2295 - accuracy: 0.9098 - val_loss: 0.2483 - val_accuracy: 0.8996
# Epoch 298/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2281 - accuracy: 0.9123 - val_loss: 0.2429 - val_accuracy: 0.9009
# Epoch 299/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2281 - accuracy: 0.9117 - val_loss: 0.2603 - val_accuracy: 0.8962
# Epoch 300/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2283 - accuracy: 0.9100 - val_loss: 0.2592 - val_accuracy: 0.8964
# Epoch 301/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2283 - accuracy: 0.9112 - val_loss: 0.2921 - val_accuracy: 0.8798
# Epoch 302/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2305 - accuracy: 0.9095 - val_loss: 0.2707 - val_accuracy: 0.8896
# Epoch 303/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2294 - accuracy: 0.9105 - val_loss: 0.2508 - val_accuracy: 0.8958
# Epoch 304/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2299 - accuracy: 0.9098 - val_loss: 0.2565 - val_accuracy: 0.8947
# Epoch 305/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2266 - accuracy: 0.9124 - val_loss: 0.2484 - val_accuracy: 0.8996
# Epoch 306/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2280 - accuracy: 0.9097 - val_loss: 0.2529 - val_accuracy: 0.8964
# Epoch 307/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2272 - accuracy: 0.9103 - val_loss: 0.2488 - val_accuracy: 0.8989
# Epoch 308/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2284 - accuracy: 0.9126 - val_loss: 0.2505 - val_accuracy: 0.8989
# Epoch 309/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2281 - accuracy: 0.9106 - val_loss: 0.2510 - val_accuracy: 0.8980
# Epoch 310/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2286 - accuracy: 0.9118 - val_loss: 0.2471 - val_accuracy: 0.8980
# Epoch 311/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2287 - accuracy: 0.9093 - val_loss: 0.2656 - val_accuracy: 0.8904
# Epoch 312/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2300 - accuracy: 0.9115 - val_loss: 0.2673 - val_accuracy: 0.8922
# Epoch 313/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2273 - accuracy: 0.9120 - val_loss: 0.2466 - val_accuracy: 0.9033
# Epoch 314/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2269 - accuracy: 0.9110 - val_loss: 0.2411 - val_accuracy: 0.9007
# Epoch 315/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2290 - accuracy: 0.9105 - val_loss: 0.2476 - val_accuracy: 0.8989
# Epoch 316/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2264 - accuracy: 0.9113 - val_loss: 0.2500 - val_accuracy: 0.8971
# Epoch 317/800
# ...
# Epoch 695/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2041 - accuracy: 0.9195 - val_loss: 0.2291 - val_accuracy: 0.9049
# Epoch 696/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2045 - accuracy: 0.9199 - val_loss: 0.2284 - val_accuracy: 0.9078
# Epoch 697/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2029 - accuracy: 0.9218 - val_loss: 0.2291 - val_accuracy: 0.9091
# Epoch 698/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2019 - accuracy: 0.9222 - val_loss: 0.2534 - val_accuracy: 0.8989
# Epoch 699/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2026 - accuracy: 0.9216 - val_loss: 0.2299 - val_accuracy: 0.9067
# Epoch 700/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2030 - accuracy: 0.9210 - val_loss: 0.2389 - val_accuracy: 0.9044
# Epoch 701/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2036 - accuracy: 0.9211 - val_loss: 0.2318 - val_accuracy: 0.9060
# Epoch 702/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2026 - accuracy: 0.9194 - val_loss: 0.2494 - val_accuracy: 0.9011
# Epoch 703/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2014 - accuracy: 0.9214 - val_loss: 0.2264 - val_accuracy: 0.9107
# Epoch 704/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2014 - accuracy: 0.9212 - val_loss: 0.2297 - val_accuracy: 0.9087
# Epoch 705/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2003 - accuracy: 0.9209 - val_loss: 0.2223 - val_accuracy: 0.9089
# Epoch 706/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2007 - accuracy: 0.9220 - val_loss: 0.2344 - val_accuracy: 0.9058
# Epoch 707/800
# 14028/14028 [==============================] - 0s 20us/step - loss: 0.2012 - accuracy: 0.9208 - val_loss: 0.2363 - val_accuracy: 0.9042
# Epoch 708/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2019 - accuracy: 0.9202 - val_loss: 0.2507 - val_accuracy: 0.8991
# Epoch 709/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2023 - accuracy: 0.9216 - val_loss: 0.2419 - val_accuracy: 0.9040
# Epoch 710/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2010 - accuracy: 0.9206 - val_loss: 0.2399 - val_accuracy: 0.9038
# Epoch 711/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2038 - accuracy: 0.9190 - val_loss: 0.2463 - val_accuracy: 0.9020
# Epoch 712/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2002 - accuracy: 0.9239 - val_loss: 0.2270 - val_accuracy: 0.9089
# Epoch 713/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2028 - accuracy: 0.9186 - val_loss: 0.2386 - val_accuracy: 0.9027
# Epoch 714/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2022 - accuracy: 0.9219 - val_loss: 0.2511 - val_accuracy: 0.9009
# Epoch 715/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2006 - accuracy: 0.9224 - val_loss: 0.2302 - val_accuracy: 0.9056
# Epoch 716/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2018 - accuracy: 0.9201 - val_loss: 0.2417 - val_accuracy: 0.9036
# Epoch 717/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2025 - accuracy: 0.9201 - val_loss: 0.2419 - val_accuracy: 0.9036
# Epoch 718/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2010 - accuracy: 0.9213 - val_loss: 0.2363 - val_accuracy: 0.9044
# Epoch 719/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2004 - accuracy: 0.9212 - val_loss: 0.2257 - val_accuracy: 0.9089
# Epoch 720/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2003 - accuracy: 0.9217 - val_loss: 0.2446 - val_accuracy: 0.9029
# Epoch 721/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2012 - accuracy: 0.9216 - val_loss: 0.2281 - val_accuracy: 0.9080
# Epoch 722/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1995 - accuracy: 0.9219 - val_loss: 0.2359 - val_accuracy: 0.9069
# Epoch 723/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2013 - accuracy: 0.9229 - val_loss: 0.2522 - val_accuracy: 0.9016
# Epoch 724/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2014 - accuracy: 0.9207 - val_loss: 0.2460 - val_accuracy: 0.9004
# Epoch 725/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2003 - accuracy: 0.9207 - val_loss: 0.2547 - val_accuracy: 0.8989
# Epoch 726/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2057 - accuracy: 0.9192 - val_loss: 0.2360 - val_accuracy: 0.9096
# Epoch 727/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1993 - accuracy: 0.9202 - val_loss: 0.2313 - val_accuracy: 0.9080
# Epoch 728/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1996 - accuracy: 0.9209 - val_loss: 0.2388 - val_accuracy: 0.9062
# Epoch 729/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2020 - accuracy: 0.9215 - val_loss: 0.2791 - val_accuracy: 0.8922
# Epoch 730/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2013 - accuracy: 0.9213 - val_loss: 0.2308 - val_accuracy: 0.9062
# Epoch 731/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1993 - accuracy: 0.9221 - val_loss: 0.2552 - val_accuracy: 0.8993
# Epoch 732/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2009 - accuracy: 0.9207 - val_loss: 0.2394 - val_accuracy: 0.9069
# Epoch 733/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2016 - accuracy: 0.9211 - val_loss: 0.2281 - val_accuracy: 0.9073
# Epoch 734/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2009 - accuracy: 0.9199 - val_loss: 0.2264 - val_accuracy: 0.9098
# Epoch 735/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2001 - accuracy: 0.9216 - val_loss: 0.2255 - val_accuracy: 0.9076
# Epoch 736/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1994 - accuracy: 0.9218 - val_loss: 0.2394 - val_accuracy: 0.9042
# Epoch 737/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2006 - accuracy: 0.9221 - val_loss: 0.2255 - val_accuracy: 0.9080
# Epoch 738/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1988 - accuracy: 0.9221 - val_loss: 0.2335 - val_accuracy: 0.9096
# Epoch 739/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.1999 - accuracy: 0.9199 - val_loss: 0.2358 - val_accuracy: 0.9058
# Epoch 740/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2016 - accuracy: 0.9217 - val_loss: 0.2260 - val_accuracy: 0.9113
# Epoch 741/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2002 - accuracy: 0.9232 - val_loss: 0.2386 - val_accuracy: 0.9053
# Epoch 742/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2006 - accuracy: 0.9205 - val_loss: 0.2407 - val_accuracy: 0.9040
# Epoch 743/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2015 - accuracy: 0.9208 - val_loss: 0.2225 - val_accuracy: 0.9096
# Epoch 744/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1992 - accuracy: 0.9224 - val_loss: 0.2366 - val_accuracy: 0.9058
# Epoch 745/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2009 - accuracy: 0.9224 - val_loss: 0.2284 - val_accuracy: 0.9082
# Epoch 746/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2002 - accuracy: 0.9219 - val_loss: 0.2229 - val_accuracy: 0.9104
# Epoch 747/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2014 - accuracy: 0.9206 - val_loss: 0.2398 - val_accuracy: 0.9004
# Epoch 748/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2008 - accuracy: 0.9207 - val_loss: 0.2273 - val_accuracy: 0.9062
# Epoch 749/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2006 - accuracy: 0.9207 - val_loss: 0.2392 - val_accuracy: 0.9038
# Epoch 750/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1993 - accuracy: 0.9216 - val_loss: 0.2347 - val_accuracy: 0.9073
# Epoch 751/800
# 14028/14028 [==============================] - 0s 20us/step - loss: 0.2001 - accuracy: 0.9222 - val_loss: 0.2231 - val_accuracy: 0.9109
# Epoch 752/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1989 - accuracy: 0.9217 - val_loss: 0.2230 - val_accuracy: 0.9120
# Epoch 753/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.1992 - accuracy: 0.9216 - val_loss: 0.2301 - val_accuracy: 0.9049
# Epoch 754/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2007 - accuracy: 0.9207 - val_loss: 0.2356 - val_accuracy: 0.9051
# Epoch 755/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2020 - accuracy: 0.9211 - val_loss: 0.2453 - val_accuracy: 0.9053
# Epoch 756/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.2006 - accuracy: 0.9221 - val_loss: 0.2337 - val_accuracy: 0.9056
# Epoch 757/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2009 - accuracy: 0.9225 - val_loss: 0.2369 - val_accuracy: 0.9049
# Epoch 758/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2005 - accuracy: 0.9213 - val_loss: 0.2265 - val_accuracy: 0.9073
# Epoch 759/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2009 - accuracy: 0.9212 - val_loss: 0.2288 - val_accuracy: 0.9078
# Epoch 760/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1993 - accuracy: 0.9227 - val_loss: 0.2212 - val_accuracy: 0.9111
# Epoch 761/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1991 - accuracy: 0.9217 - val_loss: 0.2225 - val_accuracy: 0.9089
# Epoch 762/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1984 - accuracy: 0.9233 - val_loss: 0.2605 - val_accuracy: 0.8964
# Epoch 763/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1997 - accuracy: 0.9212 - val_loss: 0.2224 - val_accuracy: 0.9096
# Epoch 764/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1981 - accuracy: 0.9208 - val_loss: 0.2295 - val_accuracy: 0.9124
# Epoch 765/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2004 - accuracy: 0.9194 - val_loss: 0.2309 - val_accuracy: 0.9084
# Epoch 766/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1988 - accuracy: 0.9226 - val_loss: 0.2375 - val_accuracy: 0.9053
# Epoch 767/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2004 - accuracy: 0.9207 - val_loss: 0.2248 - val_accuracy: 0.9107
# Epoch 768/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2014 - accuracy: 0.9212 - val_loss: 0.2597 - val_accuracy: 0.8958
# Epoch 769/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1981 - accuracy: 0.9194 - val_loss: 0.2356 - val_accuracy: 0.9064
# Epoch 770/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1991 - accuracy: 0.9214 - val_loss: 0.2365 - val_accuracy: 0.9058
# Epoch 771/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1996 - accuracy: 0.9209 - val_loss: 0.2479 - val_accuracy: 0.9009
# Epoch 772/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1987 - accuracy: 0.9218 - val_loss: 0.2651 - val_accuracy: 0.8960
# Epoch 773/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1981 - accuracy: 0.9223 - val_loss: 0.2318 - val_accuracy: 0.9076
# Epoch 774/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.1978 - accuracy: 0.9229 - val_loss: 0.2365 - val_accuracy: 0.9033
# Epoch 775/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2014 - accuracy: 0.9211 - val_loss: 0.2256 - val_accuracy: 0.9100
# Epoch 776/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2007 - accuracy: 0.9229 - val_loss: 0.2258 - val_accuracy: 0.9076
# Epoch 777/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1989 - accuracy: 0.9223 - val_loss: 0.2294 - val_accuracy: 0.9080
# Epoch 778/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.1993 - accuracy: 0.9219 - val_loss: 0.2307 - val_accuracy: 0.9098
# Epoch 779/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1991 - accuracy: 0.9222 - val_loss: 0.2296 - val_accuracy: 0.9064
# Epoch 780/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1996 - accuracy: 0.9213 - val_loss: 0.2392 - val_accuracy: 0.9033
# Epoch 781/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1986 - accuracy: 0.9237 - val_loss: 0.2625 - val_accuracy: 0.8938
# Epoch 782/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1991 - accuracy: 0.9212 - val_loss: 0.2263 - val_accuracy: 0.9087
# Epoch 783/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1992 - accuracy: 0.9218 - val_loss: 0.2376 - val_accuracy: 0.9053
# Epoch 784/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1976 - accuracy: 0.9219 - val_loss: 0.2424 - val_accuracy: 0.9042
# Epoch 785/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.2006 - accuracy: 0.9207 - val_loss: 0.2276 - val_accuracy: 0.9087
# Epoch 786/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1998 - accuracy: 0.9224 - val_loss: 0.2372 - val_accuracy: 0.9064
# Epoch 787/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1994 - accuracy: 0.9211 - val_loss: 0.2301 - val_accuracy: 0.9091
# Epoch 788/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1994 - accuracy: 0.9217 - val_loss: 0.2284 - val_accuracy: 0.9109
# Epoch 789/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1986 - accuracy: 0.9198 - val_loss: 0.2319 - val_accuracy: 0.9100
# Epoch 790/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.1987 - accuracy: 0.9229 - val_loss: 0.2292 - val_accuracy: 0.9093
# Epoch 791/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1979 - accuracy: 0.9209 - val_loss: 0.2351 - val_accuracy: 0.9058
# Epoch 792/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1970 - accuracy: 0.9218 - val_loss: 0.2213 - val_accuracy: 0.9096
# Epoch 793/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1998 - accuracy: 0.9198 - val_loss: 0.2545 - val_accuracy: 0.8973
# Epoch 794/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1981 - accuracy: 0.9231 - val_loss: 0.2431 - val_accuracy: 0.9033
# Epoch 795/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1987 - accuracy: 0.9207 - val_loss: 0.2481 - val_accuracy: 0.9024
# Epoch 796/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1979 - accuracy: 0.9218 - val_loss: 0.2269 - val_accuracy: 0.9064
# Epoch 797/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1982 - accuracy: 0.9223 - val_loss: 0.2227 - val_accuracy: 0.9113
# Epoch 798/800
# 14028/14028 [==============================] - 0s 19us/step - loss: 0.1969 - accuracy: 0.9195 - val_loss: 0.2235 - val_accuracy: 0.9124
# Epoch 799/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1981 - accuracy: 0.9219 - val_loss: 0.2391 - val_accuracy: 0.9029
# Epoch 800/800
# 14028/14028 [==============================] - 0s 18us/step - loss: 0.1991 - accuracy: 0.9229 - val_loss: 0.2304 - val_accuracy: 0.9091

# %% [markdown]
# ## Part 6: Model Evaluation

# %%
#Evaluating train accuracy
model.evaluate(X_train_smote, y_train_smote)
# Out:
# 14028/14028 [==============================] - 0s 13us/step
# [0.20377902120207325, 0.9196606874465942]

# %%
#Evaluating test accuracy
from sklearn.metrics import accuracy_score

Y_pred_nn = model.predict(X_test)
Y_pred_nn = (Y_pred_nn > 0.5)
test_accuracy_nn = accuracy_score(y_test, Y_pred_nn)
print("Test accuracy of Neural Network is " + str(test_accuracy_nn * 100))
# Out:
# Test accuracy of Neural Network is 90.91111111111111

# %%
# Creating the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, Y_pred_nn)
cm
# Out:
# array([[2760,  226],
#        [ 183, 1331]], dtype=int64)

# %%
# Classification Report
from sklearn.metrics import classification_report, precision_score, recall_score,f1_score
print(classification_report(y_test, Y_pred_nn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93      2986
#            1       0.85      0.88      0.87      1514
#
#     accuracy                           0.91      4500
#    macro avg       0.90      0.90      0.90      4500
# weighted avg       0.91      0.91      0.91      4500

# %%
#Plot of Model Accuracy vs Epoch

import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
#Plot of Model Loss vs Epoch

import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
